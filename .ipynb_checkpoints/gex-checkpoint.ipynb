# %% [markdown]
# # Advanced Employee Turnover Prediction Notebook
# This notebook contains the full pipeline with hyperparameter tuning and SMOTE.

# %%
# Out:
# Collecting scikit-learn==0.13
#   Downloading scikit-learn-0.13.tar.gz (3.5 MB)
#      ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#      - -------------------------------------- 0.1/3.5 MB 1.4 MB/s eta 0:00:03
#      ------------ --------------------------- 1.0/3.5 MB 8.3 MB/s eta 0:00:01
#      ------------ --------------------------- 1.0/3.5 MB 8.3 MB/s eta 0:00:01
#      ------------ --------------------------- 1.0/3.5 MB 8.3 MB/s eta 0:00:01
#      ------------ --------------------------- 1.0/3.5 MB 8.3 MB/s eta 0:00:01
#      ------------ --------------------------- 1.0/3.5 MB 8.3 MB/s eta 0:00:01
#      ------------ --------------------------- 1.0/3.5 MB 8.3 MB/s eta 0:00:01
#      ------------ --------------------------- 1.0/3.5 MB 8.3 MB/s eta 0:00:01
#      ------------ --------------------------- 1.0/3.5 MB 8.3 MB/s eta 0:00:01
#      ------------ --------------------------- 1.0/3.5 MB 8.3 MB/s eta 0:00:01
#      ------------------------ --------------- 2.1/3.5 MB 3.8 MB/s eta 0:00:01
#      ------------------------ --------------- 2.1/3.5 MB 3.8 MB/s eta 0:00:01
#      ------------------------ --------------- 2.1/3.5 MB 3.8 MB/s eta 0:00:01
#      ------------------------ --------------- 2.1/3.5 MB 3.8 MB/s eta 0:00:01
#      ------------------------ --------------- 2.1/3.5 MB 3.8 MB/s eta 0:00:01
#      ------------------------ --------------- 2.1/3.5 MB 3.8 MB/s eta 0:00:01
#      ------------------------ --------------- 2.1/3.5 MB 3.8 MB/s eta 0:00:01
#      ------------------------ --------------- 2.1/3.5 MB 3.8 MB/s eta 0:00:01
#      ------------------------------------ --- 3.1/3.5 MB 3.3 MB/s eta 0:00:01
#      ------------------------------------ --- 3.1/3.5 MB 3.3 MB/s eta 0:00:01
#      ------------------------------------ --- 3.1/3.5 MB 3.3 MB/s eta 0:00:01
#      ------------------------------------ --- 3.1/3.5 MB 3.3 MB/s eta 0:00:01
#      ------------------------------------ --- 3.1/3.5 MB 3.3 MB/s eta 0:00:01
#      ---------------------------------------- 3.5/3.5 MB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: scikit-learn
#   Building wheel for scikit-learn (setup.py): started
#   Building wheel for scikit-learn (setup.py): finished with status 'error'
#   Running setup.py clean for scikit-learn
# Failed to build scikit-learn
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [1003 lines of output]
#   Partial import of sklearn during the build process.
#   C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\setup.py:55: DeprecationWarning:
#
#     `numpy.distutils` is deprecated since NumPy 1.23.0, as a result
#     of the deprecation of `distutils` itself. It will be removed for
#     Python >= 3.12. For older Python versions it will remain present.
#     It is recommended to use `setuptools < 60.0` for those Python versions.
#     For more details, see:
#       https://numpy.org/devdocs/reference/distutils_status_migration.html
#
#
#     from numpy.distutils.core import setup
#   Copying source tree into build/py3k for 2to3 transformation...
#   C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\setup.py:95: DeprecationWarning: lib2to3 package is deprecated and may not be able to parse Python 3.10+
#     import lib2to3.main
#   Converting to Python3 via 2to3...
#   RefactoringTool: Skipping optional fixer: buffer
#   RefactoringTool: Skipping optional fixer: idioms
#   RefactoringTool: Skipping optional fixer: set_literal
#   RefactoringTool: Skipping optional fixer: ws_comma
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\__init__.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\_build_utils.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\base.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\cross_validation.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\dummy.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\grid_search.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\hmm.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\isotonic.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\kernel_approximation.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\lda.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\multiclass.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\naive_bayes.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\pipeline.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\pls.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\preprocessing.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\qda.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\random_projection.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\setup.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\test_setup.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\__check_build\__init__.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\__check_build\setup.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\cluster\__init__.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\cluster\_feature_agglomeration.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\cluster\affinity_propagation_.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\cluster\dbscan_.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\cluster\hierarchical.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\cluster\k_means_.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\cluster\mean_shift_.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\cluster\setup.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\cluster\spectral.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\cluster\tests\common.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\cluster\tests\test_affinity_propagation.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\cluster\tests\test_dbscan.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\cluster\tests\test_hierarchical.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\cluster\tests\test_k_means.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\cluster\tests\test_mean_shift.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\cluster\tests\test_spectral.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\covariance\__init__.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\covariance\empirical_covariance_.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\covariance\graph_lasso_.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\covariance\outlier_detection.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\covariance\robust_covariance.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\covariance\shrunk_covariance_.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\covariance\tests\test_covariance.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\covariance\tests\test_graph_lasso.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\covariance\tests\test_robust_covariance.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\datasets\__init__.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\datasets\base.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\datasets\california_housing.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\datasets\lfw.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\datasets\mlcomp.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\datasets\mldata.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\datasets\olivetti_faces.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\datasets\samples_generator.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\datasets\setup.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\datasets\species_distributions.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\datasets\svmlight_format.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\datasets\twenty_newsgroups.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\datasets\tests\test_20news.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\datasets\tests\test_base.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\datasets\tests\test_lfw.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\datasets\tests\test_mldata.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\datasets\tests\test_samples_generator.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\datasets\tests\test_svmlight_format.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\decomposition\__init__.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\decomposition\dict_learning.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\decomposition\factor_analysis.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\decomposition\fastica_.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\decomposition\kernel_pca.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\decomposition\nmf.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\decomposition\pca.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\decomposition\sparse_pca.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\decomposition\tests\test_dict_learning.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\decomposition\tests\test_factor_analysis.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\decomposition\tests\test_fastica.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\decomposition\tests\test_kernel_pca.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\decomposition\tests\test_nmf.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\decomposition\tests\test_pca.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\decomposition\tests\test_sparse_pca.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\ensemble\__init__.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\ensemble\base.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\ensemble\forest.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\ensemble\gradient_boosting.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\ensemble\partial_dependence.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\ensemble\setup.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\ensemble\tests\test_base.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\ensemble\tests\test_forest.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\ensemble\tests\test_gradient_boosting.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\ensemble\tests\test_partial_dependence.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\externals\__init__.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\externals\setup.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\externals\test_externals_setup.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\externals\joblib\__init__.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\externals\joblib\_compat.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\externals\joblib\disk.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\externals\joblib\format_stack.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\externals\joblib\func_inspect.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\externals\joblib\hashing.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\externals\joblib\logger.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\externals\joblib\memory.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\externals\joblib\my_exceptions.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\externals\joblib\numpy_pickle.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\externals\joblib\parallel.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\externals\joblib\testing.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\externals\joblib\test\common.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\externals\joblib\test\test_disk.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\externals\joblib\test\test_format_stack.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\externals\joblib\test\test_func_inspect.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\externals\joblib\test\test_hashing.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\externals\joblib\test\test_logger.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\externals\joblib\test\test_memory.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\externals\joblib\test\test_my_exceptions.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\externals\joblib\test\test_numpy_pickle.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\externals\joblib\test\test_parallel.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\feature_extraction\__init__.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\feature_extraction\dict_vectorizer.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\feature_extraction\hashing.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\feature_extraction\image.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\feature_extraction\setup.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\feature_extraction\stop_words.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\feature_extraction\text.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\feature_extraction\tests\test_dict_vectorizer.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\feature_extraction\tests\test_feature_hasher.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\feature_extraction\tests\test_image.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\feature_extraction\tests\test_text.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\feature_selection\__init__.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\feature_selection\rfe.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\feature_selection\selector_mixin.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\feature_selection\univariate_selection.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\feature_selection\tests\test_chi2.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\feature_selection\tests\test_feature_select.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\feature_selection\tests\test_rfe.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\feature_selection\tests\test_selector_mixin.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\gaussian_process\__init__.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\gaussian_process\correlation_models.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\gaussian_process\gaussian_process.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\gaussian_process\regression_models.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\gaussian_process\tests\test_gaussian_process.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\linear_model\__init__.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\linear_model\base.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\linear_model\bayes.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\linear_model\coordinate_descent.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\linear_model\least_angle.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\linear_model\logistic.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\linear_model\omp.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\linear_model\passive_aggressive.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\linear_model\perceptron.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\linear_model\randomized_l1.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\linear_model\ridge.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\linear_model\setup.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\linear_model\stochastic_gradient.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\linear_model\tests\test_base.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\linear_model\tests\test_bayes.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\linear_model\tests\test_coordinate_descent.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\linear_model\tests\test_least_angle.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\linear_model\tests\test_logistic.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\linear_model\tests\test_omp.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\linear_model\tests\test_passive_aggressive.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\linear_model\tests\test_perceptron.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\linear_model\tests\test_randomized_l1.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\linear_model\tests\test_ridge.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\linear_model\tests\test_sgd.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\linear_model\tests\test_sparse_coordinate_descent.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\manifold\__init__.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\manifold\isomap.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\manifold\locally_linear.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\manifold\mds.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\manifold\spectral_embedding.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\metrics\__init__.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\metrics\metrics.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\metrics\pairwise.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\metrics\setup.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\metrics\cluster\__init__.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\metrics\cluster\setup.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\metrics\cluster\supervised.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\metrics\cluster\unsupervised.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\metrics\cluster\tests\test_supervised.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\metrics\cluster\tests\test_unsupervised.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\metrics\tests\test_metrics.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\metrics\tests\test_pairwise.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\mixture\__init__.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\mixture\dpgmm.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\mixture\gmm.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\mixture\tests\test_dpgmm.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\mixture\tests\test_gmm.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\neighbors\__init__.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\neighbors\base.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\neighbors\classification.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\neighbors\graph.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\neighbors\nearest_centroid.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\neighbors\regression.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\neighbors\setup.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\neighbors\unsupervised.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\semi_supervised\__init__.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\semi_supervised\label_propagation.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\svm\__init__.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\svm\base.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\svm\bounds.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\svm\classes.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\svm\setup.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\svm\sparse\__init__.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\svm\sparse\base.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\svm\sparse\classes.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\svm\tests\test_bounds.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\svm\tests\test_sparse.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\svm\tests\test_svm.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\tests\test_base.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\tests\test_check_build.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\tests\test_common.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\tests\test_cross_validation.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\tests\test_dummy.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\tests\test_grid_search.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\tests\test_hmm.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\tests\test_init.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\tests\test_isotonic.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\tests\test_kernel_approximation.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\tests\test_lda.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\tests\test_multiclass.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\tests\test_naive_bayes.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\tests\test_pipeline.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\tests\test_pls.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\tests\test_preprocessing.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\tests\test_qda.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\tests\test_random_projection.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\tree\__init__.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\tree\setup.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\tree\tree.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\tree\tests\test_tree.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\utils\__init__.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\utils\_csgraph.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\utils\arpack.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\utils\bench.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\utils\class_weight.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\utils\extmath.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\utils\fixes.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\utils\graph.py
#   RefactoringTool: No changes to C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\utils\setup.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\utils\testing.py
#   RefactoringTool: Refactored C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\sklearn\utils\validation.py
# ...
#   creating build\lib.win-amd64-cpython-311\sklearn\utils\sparsetools
#   copying sklearn\utils\sparsetools\csgraph.py -> build\lib.win-amd64-cpython-311\sklearn\utils\sparsetools
#   copying sklearn\utils\sparsetools\setup.py -> build\lib.win-amd64-cpython-311\sklearn\utils\sparsetools
#   copying sklearn\utils\sparsetools\__init__.py -> build\lib.win-amd64-cpython-311\sklearn\utils\sparsetools
#   creating build\lib.win-amd64-cpython-311\sklearn\utils\tests
#   copying sklearn\utils\tests\test_bench.py -> build\lib.win-amd64-cpython-311\sklearn\utils/tests
#   copying sklearn\utils\tests\test_extmath.py -> build\lib.win-amd64-cpython-311\sklearn\utils/tests
#   copying sklearn\utils\tests\test_fixes.py -> build\lib.win-amd64-cpython-311\sklearn\utils/tests
#   copying sklearn\utils\tests\test_graph.py -> build\lib.win-amd64-cpython-311\sklearn\utils/tests
#   copying sklearn\utils\tests\test_murmurhash.py -> build\lib.win-amd64-cpython-311\sklearn\utils/tests
#   copying sklearn\utils\tests\test_random.py -> build\lib.win-amd64-cpython-311\sklearn\utils/tests
#   copying sklearn\utils\tests\test_shortest_path.py -> build\lib.win-amd64-cpython-311\sklearn\utils/tests
#   copying sklearn\utils\tests\test_sparsefuncs.py -> build\lib.win-amd64-cpython-311\sklearn\utils/tests
#   copying sklearn\utils\tests\test_testing.py -> build\lib.win-amd64-cpython-311\sklearn\utils/tests
#   copying sklearn\utils\tests\test_utils.py -> build\lib.win-amd64-cpython-311\sklearn\utils/tests
#   copying sklearn\utils\tests\test_validation.py -> build\lib.win-amd64-cpython-311\sklearn\utils/tests
#   copying sklearn\utils\tests\__init__.py -> build\lib.win-amd64-cpython-311\sklearn\utils/tests
#   creating build\lib.win-amd64-cpython-311\sklearn\externals
#   copying sklearn\externals\setup.py -> build\lib.win-amd64-cpython-311\sklearn\externals
#   copying sklearn\externals\test_externals_setup.py -> build\lib.win-amd64-cpython-311\sklearn\externals
#   copying sklearn\externals\__init__.py -> build\lib.win-amd64-cpython-311\sklearn\externals
#   creating build\lib.win-amd64-cpython-311\sklearn\externals\joblib
#   copying sklearn\externals\joblib\disk.py -> build\lib.win-amd64-cpython-311\sklearn\externals\joblib
#   copying sklearn\externals\joblib\format_stack.py -> build\lib.win-amd64-cpython-311\sklearn\externals\joblib
#   copying sklearn\externals\joblib\func_inspect.py -> build\lib.win-amd64-cpython-311\sklearn\externals\joblib
#   copying sklearn\externals\joblib\hashing.py -> build\lib.win-amd64-cpython-311\sklearn\externals\joblib
#   copying sklearn\externals\joblib\logger.py -> build\lib.win-amd64-cpython-311\sklearn\externals\joblib
#   copying sklearn\externals\joblib\memory.py -> build\lib.win-amd64-cpython-311\sklearn\externals\joblib
#   copying sklearn\externals\joblib\my_exceptions.py -> build\lib.win-amd64-cpython-311\sklearn\externals\joblib
#   copying sklearn\externals\joblib\numpy_pickle.py -> build\lib.win-amd64-cpython-311\sklearn\externals\joblib
#   copying sklearn\externals\joblib\parallel.py -> build\lib.win-amd64-cpython-311\sklearn\externals\joblib
#   copying sklearn\externals\joblib\testing.py -> build\lib.win-amd64-cpython-311\sklearn\externals\joblib
#   copying sklearn\externals\joblib\_compat.py -> build\lib.win-amd64-cpython-311\sklearn\externals\joblib
#   copying sklearn\externals\joblib\__init__.py -> build\lib.win-amd64-cpython-311\sklearn\externals\joblib
#   creating build\lib.win-amd64-cpython-311\sklearn\externals\joblib\test
#   copying sklearn\externals\joblib\test\common.py -> build\lib.win-amd64-cpython-311\sklearn\externals\joblib/test
#   copying sklearn\externals\joblib\test\test_disk.py -> build\lib.win-amd64-cpython-311\sklearn\externals\joblib/test
#   copying sklearn\externals\joblib\test\test_format_stack.py -> build\lib.win-amd64-cpython-311\sklearn\externals\joblib/test
#   copying sklearn\externals\joblib\test\test_func_inspect.py -> build\lib.win-amd64-cpython-311\sklearn\externals\joblib/test
#   copying sklearn\externals\joblib\test\test_hashing.py -> build\lib.win-amd64-cpython-311\sklearn\externals\joblib/test
#   copying sklearn\externals\joblib\test\test_logger.py -> build\lib.win-amd64-cpython-311\sklearn\externals\joblib/test
#   copying sklearn\externals\joblib\test\test_memory.py -> build\lib.win-amd64-cpython-311\sklearn\externals\joblib/test
#   copying sklearn\externals\joblib\test\test_my_exceptions.py -> build\lib.win-amd64-cpython-311\sklearn\externals\joblib/test
#   copying sklearn\externals\joblib\test\test_numpy_pickle.py -> build\lib.win-amd64-cpython-311\sklearn\externals\joblib/test
#   copying sklearn\externals\joblib\test\test_parallel.py -> build\lib.win-amd64-cpython-311\sklearn\externals\joblib/test
#   copying sklearn\externals\joblib\test\__init__.py -> build\lib.win-amd64-cpython-311\sklearn\externals\joblib/test
#   creating build\lib.win-amd64-cpython-311\sklearn\mixture
#   copying sklearn\mixture\dpgmm.py -> build\lib.win-amd64-cpython-311\sklearn\mixture
#   copying sklearn\mixture\gmm.py -> build\lib.win-amd64-cpython-311\sklearn\mixture
#   copying sklearn\mixture\__init__.py -> build\lib.win-amd64-cpython-311\sklearn\mixture
#   creating build\lib.win-amd64-cpython-311\sklearn\mixture\tests
#   copying sklearn\mixture\tests\test_dpgmm.py -> build\lib.win-amd64-cpython-311\sklearn\mixture/tests
#   copying sklearn\mixture\tests\test_gmm.py -> build\lib.win-amd64-cpython-311\sklearn\mixture/tests
#   copying sklearn\mixture\tests\__init__.py -> build\lib.win-amd64-cpython-311\sklearn\mixture/tests
#   creating build\lib.win-amd64-cpython-311\sklearn\gaussian_process
#   copying sklearn\gaussian_process\correlation_models.py -> build\lib.win-amd64-cpython-311\sklearn\gaussian_process
#   copying sklearn\gaussian_process\gaussian_process.py -> build\lib.win-amd64-cpython-311\sklearn\gaussian_process
#   copying sklearn\gaussian_process\regression_models.py -> build\lib.win-amd64-cpython-311\sklearn\gaussian_process
#   copying sklearn\gaussian_process\__init__.py -> build\lib.win-amd64-cpython-311\sklearn\gaussian_process
#   creating build\lib.win-amd64-cpython-311\sklearn\gaussian_process\tests
#   copying sklearn\gaussian_process\tests\test_gaussian_process.py -> build\lib.win-amd64-cpython-311\sklearn\gaussian_process/tests
#   copying sklearn\gaussian_process\tests\__init__.py -> build\lib.win-amd64-cpython-311\sklearn\gaussian_process/tests
#   creating build\lib.win-amd64-cpython-311\sklearn\neighbors
#   copying sklearn\neighbors\base.py -> build\lib.win-amd64-cpython-311\sklearn\neighbors
#   copying sklearn\neighbors\classification.py -> build\lib.win-amd64-cpython-311\sklearn\neighbors
#   copying sklearn\neighbors\graph.py -> build\lib.win-amd64-cpython-311\sklearn\neighbors
#   copying sklearn\neighbors\nearest_centroid.py -> build\lib.win-amd64-cpython-311\sklearn\neighbors
#   copying sklearn\neighbors\regression.py -> build\lib.win-amd64-cpython-311\sklearn\neighbors
#   copying sklearn\neighbors\setup.py -> build\lib.win-amd64-cpython-311\sklearn\neighbors
#   copying sklearn\neighbors\unsupervised.py -> build\lib.win-amd64-cpython-311\sklearn\neighbors
#   copying sklearn\neighbors\__init__.py -> build\lib.win-amd64-cpython-311\sklearn\neighbors
#   creating build\lib.win-amd64-cpython-311\sklearn\manifold
#   copying sklearn\manifold\isomap.py -> build\lib.win-amd64-cpython-311\sklearn\manifold
#   copying sklearn\manifold\locally_linear.py -> build\lib.win-amd64-cpython-311\sklearn\manifold
#   copying sklearn\manifold\mds.py -> build\lib.win-amd64-cpython-311\sklearn\manifold
#   copying sklearn\manifold\spectral_embedding.py -> build\lib.win-amd64-cpython-311\sklearn\manifold
#   copying sklearn\manifold\__init__.py -> build\lib.win-amd64-cpython-311\sklearn\manifold
#   creating build\lib.win-amd64-cpython-311\sklearn\metrics
#   copying sklearn\metrics\metrics.py -> build\lib.win-amd64-cpython-311\sklearn\metrics
#   copying sklearn\metrics\pairwise.py -> build\lib.win-amd64-cpython-311\sklearn\metrics
#   copying sklearn\metrics\setup.py -> build\lib.win-amd64-cpython-311\sklearn\metrics
#   copying sklearn\metrics\__init__.py -> build\lib.win-amd64-cpython-311\sklearn\metrics
#   creating build\lib.win-amd64-cpython-311\sklearn\semi_supervised
#   copying sklearn\semi_supervised\label_propagation.py -> build\lib.win-amd64-cpython-311\sklearn\semi_supervised
#   copying sklearn\semi_supervised\__init__.py -> build\lib.win-amd64-cpython-311\sklearn\semi_supervised
#   creating build\lib.win-amd64-cpython-311\sklearn\tree
#   copying sklearn\tree\setup.py -> build\lib.win-amd64-cpython-311\sklearn\tree
#   copying sklearn\tree\tree.py -> build\lib.win-amd64-cpython-311\sklearn\tree
#   copying sklearn\tree\__init__.py -> build\lib.win-amd64-cpython-311\sklearn\tree
#   creating build\lib.win-amd64-cpython-311\sklearn\tree\tests
#   copying sklearn\tree\tests\test_tree.py -> build\lib.win-amd64-cpython-311\sklearn\tree\tests
#   copying sklearn\tree\tests\__init__.py -> build\lib.win-amd64-cpython-311\sklearn\tree\tests
#   creating build\lib.win-amd64-cpython-311\sklearn\metrics\tests
#   copying sklearn\metrics\tests\test_metrics.py -> build\lib.win-amd64-cpython-311\sklearn\metrics/tests
#   copying sklearn\metrics\tests\test_pairwise.py -> build\lib.win-amd64-cpython-311\sklearn\metrics/tests
#   copying sklearn\metrics\tests\__init__.py -> build\lib.win-amd64-cpython-311\sklearn\metrics/tests
#   creating build\lib.win-amd64-cpython-311\sklearn\metrics\cluster
#   copying sklearn\metrics\cluster\setup.py -> build\lib.win-amd64-cpython-311\sklearn\metrics/cluster
#   copying sklearn\metrics\cluster\supervised.py -> build\lib.win-amd64-cpython-311\sklearn\metrics/cluster
#   copying sklearn\metrics\cluster\unsupervised.py -> build\lib.win-amd64-cpython-311\sklearn\metrics/cluster
#   copying sklearn\metrics\cluster\__init__.py -> build\lib.win-amd64-cpython-311\sklearn\metrics/cluster
#   creating build\lib.win-amd64-cpython-311\sklearn\metrics\cluster\tests
#   copying sklearn\metrics\cluster\tests\test_supervised.py -> build\lib.win-amd64-cpython-311\sklearn\metrics/cluster\tests
#   copying sklearn\metrics\cluster\tests\test_unsupervised.py -> build\lib.win-amd64-cpython-311\sklearn\metrics/cluster\tests
#   copying sklearn\metrics\cluster\tests\__init__.py -> build\lib.win-amd64-cpython-311\sklearn\metrics/cluster\tests
#   creating build\lib.win-amd64-cpython-311\sklearn\linear_model
#   copying sklearn\linear_model\base.py -> build\lib.win-amd64-cpython-311\sklearn\linear_model
#   copying sklearn\linear_model\bayes.py -> build\lib.win-amd64-cpython-311\sklearn\linear_model
#   copying sklearn\linear_model\coordinate_descent.py -> build\lib.win-amd64-cpython-311\sklearn\linear_model
#   copying sklearn\linear_model\least_angle.py -> build\lib.win-amd64-cpython-311\sklearn\linear_model
#   copying sklearn\linear_model\logistic.py -> build\lib.win-amd64-cpython-311\sklearn\linear_model
#   copying sklearn\linear_model\omp.py -> build\lib.win-amd64-cpython-311\sklearn\linear_model
#   copying sklearn\linear_model\passive_aggressive.py -> build\lib.win-amd64-cpython-311\sklearn\linear_model
#   copying sklearn\linear_model\perceptron.py -> build\lib.win-amd64-cpython-311\sklearn\linear_model
#   copying sklearn\linear_model\randomized_l1.py -> build\lib.win-amd64-cpython-311\sklearn\linear_model
#   copying sklearn\linear_model\ridge.py -> build\lib.win-amd64-cpython-311\sklearn\linear_model
#   copying sklearn\linear_model\setup.py -> build\lib.win-amd64-cpython-311\sklearn\linear_model
#   copying sklearn\linear_model\stochastic_gradient.py -> build\lib.win-amd64-cpython-311\sklearn\linear_model
#   copying sklearn\linear_model\__init__.py -> build\lib.win-amd64-cpython-311\sklearn\linear_model
#   creating build\lib.win-amd64-cpython-311\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_base.py -> build\lib.win-amd64-cpython-311\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_bayes.py -> build\lib.win-amd64-cpython-311\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_coordinate_descent.py -> build\lib.win-amd64-cpython-311\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_least_angle.py -> build\lib.win-amd64-cpython-311\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_logistic.py -> build\lib.win-amd64-cpython-311\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_omp.py -> build\lib.win-amd64-cpython-311\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_passive_aggressive.py -> build\lib.win-amd64-cpython-311\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_perceptron.py -> build\lib.win-amd64-cpython-311\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_randomized_l1.py -> build\lib.win-amd64-cpython-311\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_ridge.py -> build\lib.win-amd64-cpython-311\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_sgd.py -> build\lib.win-amd64-cpython-311\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_sparse_coordinate_descent.py -> build\lib.win-amd64-cpython-311\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\__init__.py -> build\lib.win-amd64-cpython-311\sklearn\linear_model\tests
#   creating build\lib.win-amd64-cpython-311\sklearn\tests
#   copying sklearn\tests\test_base.py -> build\lib.win-amd64-cpython-311\sklearn\tests
#   copying sklearn\tests\test_check_build.py -> build\lib.win-amd64-cpython-311\sklearn\tests
#   copying sklearn\tests\test_common.py -> build\lib.win-amd64-cpython-311\sklearn\tests
#   copying sklearn\tests\test_cross_validation.py -> build\lib.win-amd64-cpython-311\sklearn\tests
#   copying sklearn\tests\test_dummy.py -> build\lib.win-amd64-cpython-311\sklearn\tests
#   copying sklearn\tests\test_grid_search.py -> build\lib.win-amd64-cpython-311\sklearn\tests
#   copying sklearn\tests\test_hmm.py -> build\lib.win-amd64-cpython-311\sklearn\tests
#   copying sklearn\tests\test_init.py -> build\lib.win-amd64-cpython-311\sklearn\tests
#   copying sklearn\tests\test_isotonic.py -> build\lib.win-amd64-cpython-311\sklearn\tests
#   copying sklearn\tests\test_kernel_approximation.py -> build\lib.win-amd64-cpython-311\sklearn\tests
#   copying sklearn\tests\test_lda.py -> build\lib.win-amd64-cpython-311\sklearn\tests
#   copying sklearn\tests\test_multiclass.py -> build\lib.win-amd64-cpython-311\sklearn\tests
#   copying sklearn\tests\test_naive_bayes.py -> build\lib.win-amd64-cpython-311\sklearn\tests
#   copying sklearn\tests\test_pipeline.py -> build\lib.win-amd64-cpython-311\sklearn\tests
#   copying sklearn\tests\test_pls.py -> build\lib.win-amd64-cpython-311\sklearn\tests
#   copying sklearn\tests\test_preprocessing.py -> build\lib.win-amd64-cpython-311\sklearn\tests
#   copying sklearn\tests\test_qda.py -> build\lib.win-amd64-cpython-311\sklearn\tests
#   copying sklearn\tests\test_random_projection.py -> build\lib.win-amd64-cpython-311\sklearn\tests
#   copying sklearn\tests\__init__.py -> build\lib.win-amd64-cpython-311\sklearn\tests
#   running build_clib
#   INFO: No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   INFO: customize MSVCCompiler
#   WARN: Missing compiler_cxx fix for MSVCCompiler
#   INFO: customize MSVCCompiler using build_clib
#   INFO: CCompilerOpt.cc_test_flags[1077] : testing flags (/O2)
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   INFO: CCompilerOpt.cache_flush[857] : write cache to path -> C:\Users\Rajiv Arora\AppData\Local\Temp\pip-install-bvzlj718\scikit-learn_fbdbadc94b6c4e0999079c89e7e0f0ff\build\py3k\build\temp.win-amd64-cpython-311\ccompiler_opt_cache_clib.py
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for scikit-learn
# ERROR: Could not build wheels for scikit-learn, which is required to install pyproject.toml-based projects

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, VotingClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report, confusion_matrix
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.feature_selection import SelectKBest, f_classif
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImbPipeline
import pickle
import warnings

warnings.filterwarnings('ignore')
RANDOM_STATE = 42
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 10
#       8 from sklearn.compose import ColumnTransformer
#       9 from sklearn.feature_selection import SelectKBest, f_classif
# ---> 10 from imblearn.over_sampling import SMOTE
#      11 from imblearn.pipeline import Pipeline as ImbPipeline
#      12 import pickle
#
# File ~\anaconda3\Lib\site-packages\imblearn\__init__.py:52
#      48     sys.stderr.write("Partial import of imblearn during the build process.\n")
#      49     # We are not importing the rest of scikit-learn during the build
#      50     # process, as it may not be compiled yet
#      51 else:
# ---> 52     from . import (
#      53         combine,
#      54         ensemble,
#      55         exceptions,
#      56         metrics,
#      57         over_sampling,
#      58         pipeline,
#      59         tensorflow,
#      60         under_sampling,
#      61         utils,
#      62     )
#      63     from ._version import __version__
#      64     from .base import FunctionSampler
#
# File ~\anaconda3\Lib\site-packages\imblearn\combine\__init__.py:5
#       1 """The :mod:`imblearn.combine` provides methods which combine
#       2 over-sampling and under-sampling.
#       3 """
# ----> 5 from ._smote_enn import SMOTEENN
#       6 from ._smote_tomek import SMOTETomek
#       8 __all__ = ["SMOTEENN", "SMOTETomek"]
#
# File ~\anaconda3\Lib\site-packages\imblearn\combine\_smote_enn.py:12
#       9 from sklearn.base import clone
#      10 from sklearn.utils import check_X_y
# ---> 12 from ..base import BaseSampler
#      13 from ..over_sampling import SMOTE
#      14 from ..over_sampling.base import BaseOverSampler
#
# File ~\anaconda3\Lib\site-packages\imblearn\base.py:21
#      18 from sklearn.utils.multiclass import check_classification_targets
#      20 from .utils import check_sampling_strategy, check_target_type
# ---> 21 from .utils._param_validation import validate_parameter_constraints
#      22 from .utils._validation import ArraysTransformer
#      25 class SamplerMixin(BaseEstimator, metaclass=ABCMeta):
#
# File ~\anaconda3\Lib\site-packages\imblearn\utils\_param_validation.py:908
#     906 from sklearn.utils._param_validation import generate_valid_param  # noqa
#     907 from sklearn.utils._param_validation import validate_parameter_constraints  # noqa
# --> 908 from sklearn.utils._param_validation import (
#     909     HasMethods,
#     910     Hidden,
#     911     Interval,
#     912     Options,
#     913     StrOptions,
#     914     _ArrayLikes,
#     915     _Booleans,
#     916     _Callables,
#     917     _CVObjects,
#     918     _InstancesOf,
#     919     _IterablesNotString,
#     920     _MissingValues,
#     921     _NoneConstraint,
#     922     _PandasNAConstraint,
#     923     _RandomStates,
#     924     _SparseMatrices,
#     925     _VerboseHelper,
#     926     make_constraint,
#     927     validate_params,
#     928 )
#
# ImportError: cannot import name '_MissingValues' from 'sklearn.utils._param_validation' (C:\Users\Rajiv Arora\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py)

# %%
def load_data() -> pd.DataFrame:
    """Load turnover.csv from script directory or CWD."""
    script_dir = Path().resolve()
    cwd = Path.cwd().resolve()
    for location in (script_dir / "turnover.csv", cwd / "turnover.csv"):
        if location.exists():
            df = pd.read_csv(location, encoding="ISO-8859-1")
            print(f"Loaded {df.shape[0]}×{df.shape[1]} from {location}")
            return df
    raise FileNotFoundError("turnover.csv not found.")

def feature_engineering(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    df['tenure_years'] = df['stag'] / 12.0
    df['age_group'] = pd.cut(df['age'], bins=[0,25,35,45,100], labels=['Young','Mid','Senior','Veteran'])
    df['personality_score'] = df[['extraversion','independ','selfcontrol','anxiety','novator']].mean(axis=1)
    df['stress_level'] = df['anxiety'] + df['selfcontrol']
    df['adaptability'] = df['novator'] + df['extraversion']
    df['tenure_age_ratio'] = df['tenure_years'] / df['age']
    df['coaching_impact'] = (df['coach']=='yes').astype(int) * df['personality_score']
    df['high_risk'] = ((df['stag']<12)&(df['age']<30)).astype(int)
    df['low_risk'] = ((df['stag']>60)&(df['age']>35)).astype(int)
    return df

def build_preprocessor(cat_cols, num_cols):
    return ColumnTransformer([
        ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), cat_cols),
        ('num', StandardScaler(), num_cols)
    ])

def tune_classifier(pipeline, param_grid, X_train, y_train, name):
    grid = GridSearchCV(pipeline, param_grid, cv=5, scoring='accuracy', n_jobs=-1, verbose=1)
    grid.fit(X_train, y_train)
    print(f"Best {name} params: {grid.best_params_}")
    return grid.best_estimator_

# %%
# Load and prepare data
df = load_data()
df = feature_engineering(df)
y = df.pop('event')
X = df

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=RANDOM_STATE)

# Define columns
cat_cols = ['gender','industry','profession','traffic','coach','head_gender','greywage','way','age_group']
num_cols = [c for c in X.columns if c not in cat_cols]

# Preprocessor
preproc = build_preprocessor(cat_cols, num_cols)

# Pipelines and parameter grids
rf_pipe = ImbPipeline([('prep', preproc), ('select', SelectKBest(f_classif, k=50)), ('smote', SMOTE(random_state=RANDOM_STATE)), ('clf', RandomForestClassifier(random_state=RANDOM_STATE, n_jobs=-1))])
rf_params = {'clf__n_estimators':[200,300], 'clf__max_depth':[10,15], 'clf__min_samples_split':[4,5], 'clf__min_samples_leaf':[1,2]}

gb_pipe = ImbPipeline([('prep', preproc), ('select', SelectKBest(f_classif, k=50)), ('smote', SMOTE(random_state=RANDOM_STATE)), ('clf', GradientBoostingClassifier(random_state=RANDOM_STATE))])
gb_params = {'clf__n_estimators':[100,200], 'clf__learning_rate':[0.05,0.1], 'clf__max_depth':[6,8], 'clf__min_samples_split':[3,5], 'clf__min_samples_leaf':[1,3]}

# Tune models
best_rf = tune_classifier(rf_pipe, rf_params, X_train, y_train, 'RandomForest')
best_gb = tune_classifier(gb_pipe, gb_params, X_train, y_train, 'GradientBoosting')

# Final ensemble
vote_clf = VotingClassifier(estimators=[('rf', best_rf.named_steps['clf']), ('gb', best_gb.named_steps['clf'])], voting='soft', n_jobs=-1)
final_pipe = ImbPipeline([('prep', preproc), ('select', SelectKBest(f_classif, k=50)), ('smote', SMOTE(random_state=RANDOM_STATE)), ('vote', vote_clf)])
final_pipe.fit(X_train, y_train)

# Evaluate
y_pred = final_pipe.predict(X_test)
print('Accuracy:', accuracy_score(y_test, y_pred))
print('ROC AUC:', roc_auc_score(y_test, final_pipe.predict_proba(X_test)[:,1]))
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))

# Save model
with open('employee_turnover_optimized.pkl','wb') as f:
    pickle.dump(final_pipe, f)
# Out:
# Loaded 1129×16 from C:\Users\Rajiv Arora\Desktop\Random Forest\turnover.csv
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 8
#       5 X = df
#       7 # Train/test split
# ----> 8 X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=RANDOM_STATE)
#      10 # Define columns
#      11 cat_cols = ['gender','industry','profession','traffic','coach','head_gender','greywage','way','age_group']
#
# NameError: name 'RANDOM_STATE' is not defined
